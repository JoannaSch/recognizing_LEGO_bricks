# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('data_array2.npy')

# %%
target = np.load('target_array2.npy')

# %%
data[0]
# Out:
# array([[[192, 190, 190],
#         [156, 154, 154],
#         [133, 131, 131],
#         ...,
#         [208, 206, 218],
#         [204, 202, 214],
#         [201, 199, 211]],
#
#        [[193, 191, 191],
#         [170, 168, 168],
#         [155, 153, 153],
#         ...,
#         [206, 204, 216],
#         [203, 201, 213],
#         [200, 198, 210]],
#
#        [[150, 150, 150],
#         [154, 154, 154],
#         [170, 169, 171],
#         ...,
#         [204, 204, 216],
#         [201, 201, 213],
#         [198, 198, 210]],
#
#        ...,
#
#        [[107, 137, 148],
#         [103, 134, 143],
#         [ 99, 129, 140],
#         ...,
#         [ 42,  38,  37],
#         [ 52,  48,  47],
#         [ 59,  55,  54]],
#
#        [[122, 162, 174],
#         [118, 159, 168],
#         [113, 151, 163],
#         ...,
#         [ 50,  50,  50],
#         [ 59,  59,  59],
#         [ 59,  61,  61]],
#
#        [[128, 174, 185],
#         [124, 170, 181],
#         [122, 164, 176],
# ...

# %%
plt.imshow(data[0])
plt.show()

# %%
target[0]
# Out:
# '2357'
